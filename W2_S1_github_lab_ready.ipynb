# %% [markdown]
# # GCAP3226 Week 2
# ## GitHub, Codespaces & green-light run test
#
# **Goal:** Leave this session **lab ready** for Week 3 (regression).
#
# **Before you start:**
# 1. GitHub account
# 2. **Fork** the instructor's Week 2 repo to **your** account
# 3. **Code → Codespaces → Create codespace** from **your fork**
#
# Full step-by-step: see `README_WEEK2.md` in this repo.
#
# **Do not** copy file paths from your Desktop or Downloads folder.

# %% [markdown]
# ## 1. Words we use (plain language)
#
# | Word | Meaning |
# |------|--------|
# | **Fork** | Your personal copy of the course repo |
# | **Codespace** | Browser classroom computer with your repo open |
# | **Save** | `File → Save` — keeps work in this session |
# | **Commit / Push** | Optional: upload a saved snapshot to **your fork** online |
#
# Discuss with a neighbour: *Why fork instead of editing the instructor's repo?*

# %% [markdown]
# ## 2. Green-light — imports
#
# Run the next cell. Raise your hand only if you see an error.

# %%
# Purpose of this cell:
# Check that the Codespace Python tools we need are available.
# - pandas  = load and work with tables (like Excel in Python)
# - matplotlib = draw charts
# If this cell runs without a red error, your environment is ready for the next steps.

import pandas as pd
import matplotlib.pyplot as plt

print("Imports OK — you are on the right track.")
# Out:
# Imports OK — you are on the right track.

# %% [markdown]
# ## 3. Green-light — load course data
#
# The CSV is **in this repo**, next to the notebook. Survey wording is on the Week 2 slides.

# %%
# Purpose of this cell:
# Load the course survey data (week2.csv) from THIS repo folder 
# "shape" = how many rows and columns the table has (like Excel: rows × columns).
# .head() shows the first few rows so you can peek at the data.

from pathlib import Path

DATA_FILE = "week2.csv"

def load_week2_data():
    candidates = [
        Path(DATA_FILE),
        Path.cwd() / DATA_FILE,
    ]
    for p in candidates:
        if p.is_file():
            print(f"Using data file: {p.resolve()}")
            return pd.read_csv(p)
    raise FileNotFoundError(
        f"Could not find {DATA_FILE}. Use a Codespace from your fork; "
        "do not use a path from your own computer."
    )

df = load_week2_data()
print("shape:", df.shape)
df.head()
# Out:
# Using data file: /workspaces/GCAP3226_week2/week2.csv
# shape: (97, 43)
#    ID  support_info  support_after_info  fairness  government_consideration  \
# 0   1             1                   1         1                         1
# 1   2             5                   5         5                         5
# 2   3             3                   5         5                         4
# 3   4             1                   2         2                         1
# 4   5             1                   3         4                         3
#
#    policy_helpfulness_original  policy_helpfulness  waste_severity  \
# 0                            1                   1               3
# 1                            5                   4               2
# 2                            2                   2               3
# 3                            2                   2               3
# 4                            1                   1               3
#
#    recycling_effort food_waste_behavior  ...  recycle_frequency  \
# 0                 1          never_seen  ...                  1
# 1                 2          never_seen  ...                  2
# 2                 1       seen_not_used  ...                  1
# 3                 2          never_seen  ...                  2
# 4                 2       seen_not_used  ...                  2
#
#    household_size  Q1_score  Q2_score  Q3_score  total_score  height  \
# 0               0         0         1         0            1    1.72
# 1               1         0         1         1            2    1.85
# 2               3         0         1         0            1    1.72
# 3               0         0         1         1            2    1.67
# 4               2         0         1         1            2    1.84
#
#    Distance to Nearest Recycling Facility       error  Distance_artificial
# 0                                     400  -10.263397           259.826667
# 1                                     300   90.062855           260.040000
# 2                                     400  108.336080           338.893333
# 3                                     300  -11.113667           192.593333
# 4                                     300   49.418514           232.946667
#
# [5 rows x 43 columns]

# %% [markdown]
# ## 4. Green-light — one plot
#
# Pick **one** column that looks categorical or numeric in `df.columns` below.
# Use Copilot if you like: write a `#` comment describing what you want, then **verify** the chart makes sense.

# %%
# Purpose of this cell:
# List every column name in the table (like Excel header row).
# Read this list so you can choose one column for the next plot.

print("Columns in this dataset:")
print(list(df.columns))
# Out:
# Columns in this dataset:
# ['ID', 'support_info', 'support_after_info', 'fairness', 'government_consideration', 'policy_helpfulness_original', 'policy_helpfulness', 'waste_severity', 'recycling_effort', 'food_waste_behavior', 'LocalResidentcode', 'DailyWasteBags_More than 1 bag', 'DailyWasteBags_Less than 1 bag', 'DailyWasteBags_Exactly 1 bag', 'HousingType_Publicrentalhousing', 'HousingType_Other', 'HousingType_Private housing', 'HousingType_Subsidized housing', 'AgeRange_18-24', 'AgeRange_25-34', 'AgeRange_35-44', 'AgeRange_45-54', 'AgeRange_55-64', 'AgeRange_65+', 'HighestEducationLevel_Secondary', 'HighestEducationLevel_DiplomaorBachelor', 'HighestEducationLevel_Primaryorbelow', 'HighestEducationLevel_Masterorabove', 'HouseholdMonthlyIncomeRange_15,001-30,000', 'HouseholdMonthlyIncomeRange_30,001-50,000', 'HouseholdMonthlyIncomeRange_50,001-70,000', 'HouseholdMonthlyIncomeRange_AboveHK70k', 'HouseholdMonthlyIncomeRange_Below15k', 'recycle_frequency', 'household_size', 'Q1_score', 'Q2_score', 'Q3_score', 'total_score', 'height', 'Distance to Nearest Recycling Facility', 'error', 'Distance_artificial']

# %%
# Purpose of this cell:
# Make ONE simple chart from one column — a green-light check that plotting works.
# - If the column has few categories → bar chart (counts)
# - If the column is numeric with many values → histogram
# You may change "col" to another name from the list above.
# Association in a chart is not proof of causation.

# TODO: choose one column and make one simple plot (bar chart or histogram)
# Example starter — edit the column name after you inspect df.columns
col = "support_info"  # change if needed

if df[col].dtype == "object" or df[col].nunique() < 15:
    counts = df[col].value_counts().sort_index().reindex(range(1, 6), fill_value=0)
    label_map = {
        1: "strongly oppose",
        2: "oppose",
        3: "neutral",
        4: "agree",
        5: "strongly agree",
    }
    ax = counts.plot(kind="bar", title=f"Counts of {col}")
    ax.set_xticklabels([label_map.get(i, str(i)) for i in range(1, 6)], rotation=0)
    ax.set_xlabel("Response")
else:
    df[col].hist(bins=15)
    plt.title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Copilot verify checklist (CILO4)
#
# If you used Copilot, answer briefly:
#
# 1. What did you ask it to do?
# 2. Did the output look right? If not, what did you change?

# %%
copilot_reflection = """
1. Prompt / task:
2. Verify / edit:
"""
print(copilot_reflection)
# Out:
# 1. Prompt / task:
# 2. Verify / edit:

# %% [markdown]
# ## 6. Exit ticket — lab ready?
#
# Check all that apply:
#
# - [ ] I am working in **my fork**, not only the instructor's repo
# - [ ] Imports ran without error
# - [ ] `week2.csv` loaded; I see `shape`
# - [ ] I made at least one plot
# - [ ] I know how to **Save** the notebook and **Download** for Moodle if needed
#
# **Next:** `W2_S2_data_visualization.ipynb` — more charts with Copilot.
# **Week 3:** regression — same fork + Codespace workflow; no GitHub re-teach.
